# %%
import numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# # 2. Visualisasi plot distribusi setiap kolom numerik.

# %%
def visualize_col(col):
    f, [ax1, ax2] = plt.subplots(1,2,figsize=(13,5))
    f.tight_layout()
    f.set_facecolor('white')

    ax1.hist(df[col])
    ax1.set(title='Histogram Data ' + col, xlabel = col, ylabel='frekuensi')
    ax1.grid()

    ax2.boxplot(df['chlorides'], showmeans=True)
    ax2.set(title='Boxplot Data ' + col, ylabel='frekuensi')
    ax2.grid()
    
    f.subplots_adjust(wspace=0.2)

    plt.show()

# %%
visualize_col('fixed acidity')

# %%
visualize_col('volatile acidity')

# %%
visualize_col('citric acid')

# %%
visualize_col('residual sugar')

# %%
visualize_col('chlorides')

# %%
visualize_col('free sulfur dioxide')

# %%
visualize_col('total sulfur dioxide')

# %%
visualize_col('density')

# %%
visualize_col('pH')

# %%
visualize_col('sulphates')

# %%
visualize_col('alcohol')

# %%
visualize_col('quality')

# %% [markdown]
# # 3. Normality Test Setiap Kolom Numerik.

# %%
def normality_test(col):
    plt.figure(facecolor='white', figsize=(7,5))
    plt.hist(df[col], density=True)
    plt.title('Histogram Data ' + col)
    plt.grid()


    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    ymed = (ymin + ymax) / 2
    mu, std = stats.norm.fit(df[col]) 
    x = np.linspace(xmin, xmax, 100)
    p = stats.norm.pdf(x, mu, std)

    plt.plot(x, p, 'k', linewidth=2)


    z, pval = stats.normaltest(df[col])
    mmmm, nnnn = stats.normaltest(df['volatile acidity'])
    txt = 'p value = ' + str(round(pval,15))
    txt += '\np value = ' + str(round(nnnn,15))
    if pval < 0.05:
        txt += '\n\nData ' + col + '\ntidak berdistribusi normal'
    else:
        txt += '\n\nData ' + col + '\nberdistribusi normal'

    plt.text(1.1*xmax, ymed, txt, fontsize='large', color='red', family='monospace')

    plt.show()

# %%
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %%
normality_test('fixed acidity')

# %%
normality_test('volatile acidity')

# %%
normality_test('citric acid')
